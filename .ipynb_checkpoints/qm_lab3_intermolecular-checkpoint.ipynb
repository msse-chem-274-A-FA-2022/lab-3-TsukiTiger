# %% [markdown]
# # Intermolecular Potential Energy Surfaces
#
# ## Definitions
# **Potential Energy Surface**: the energy of a system or collection of atoms, in terms of certain parameters, normally the positions of the atoms. [reference](https://chem.libretexts.org/Courses/University_of_California_Davis/UCD_Chem_107B%3A_Physical_Chemistry_for_Life_Scientists/Chapters/2%3A_Chemical_Kinetics/2.06%3A_Potential_Energy_Surfaces).
#
# ## Goals
# In this exercise we will scan the intermolecular potential energy surfaces of a pair of molecules (dimer): the water dimer.

# %% [markdown]
# ## Loading required modules and functions

# %%
import psi4
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Specifying water dimer geometry
# Here you will setup your the potential energy surface scans. The first step is to create your molecule using what is called a z-matrix specification. In this type of geometry specification, you specify the geometry of a molecule through connectivity, that is, by listing each atom and defining its connectivity to other atoms.

# %%
# set the amount of memory that you will need
psi4.set_memory('500 MB')

# set the molecule name for your files and plots
molecule_name = "h2o-dimer"

# Define water dimer
water_dimer = """
O1
H2 1 1.0
H3 1 1.0 2 104.52
x4 2 1.0 1 90.0 3 180.0
--
O5 2 **R** 4 90.0 1 180.0
H6 5 1.0 2 120.0 4 90.0
H7 5 1.0 2 120.0 4 -90.0
"""
# Out:
#   Memory set to 476.837 MiB by Python driver.

# %% [markdown]
# ## Scan 1D PES
# Now we will perform a one-dimensional (1D) scan of the water dimer as the intermolecular distance between the two molecules is increased. The scan will be performed along the vector connecting the two oxygen atoms of the molecule.
#
# Since the monomer geometries are not changing and since we don’t care about the absolute energy, we will be computing the interaction energy. For a dimer the interaction energy is calculated by subtracting the energy of the monomers from the energy of the dimer. This is done automatically by using the command `bsse_type='cp'`.

# %%
rvals = [1.4, 1.5, 1.6, 1.7, 1.8, 1.9, 2.0, 2.1, 2.2, 2.3, 2.4, 2.5, 3.0, 3.5]
energies = []
for r in rvals:
    # Build a new molecule at each separation
    mol = psi4.geometry(water_dimer.replace('**R**', str(r)))

    # Compute the interaction energy
    E = psi4.energy('scf/aug-cc-pVDZ', molecule=mol, bsse_type='cp')

    # Place in a reasonable unit, kcal/mole in this case
    E = E*627.509

    # Append the value to our list
    energies.append(E)

print("Finished computing the potential energy surface!")
# Out:
# Scratch directory: /tmp/
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   // ManyBody Setup: N-Body Levels [1, 2]//
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#         Number of 1-body computations:     2
#         Number of 2-body computations:     1
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.6.1 release
#
#                          Git: Rev {HEAD} 5b9f6e3
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, and A. Jiang
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     http://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Tuesday, 27 September 2022 11:45PM
#
#     Process ID: 93892
#     Host:       Chongyes-Air.attlocal.net
#     PSIDATADIR: /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4
#     Memory:     476.8 MiB
#     Threads:    1
#
#   ==> Input QCSchema <==
#
# --------------------------------------------------------------------------
# {'driver': 'energy',
#  'extras': {'psiapi': True, 'wfn_qcvars_only': True},
#  'id': None,
#  'keywords': {'function_kwargs': {}},
#  'model': {'basis': 'aug-cc-pvdz', 'method': 'scf'},
#  'molecule': {'atom_labels': ['1', '2', '3', '5', '6', '7'],
#               'atomic_numbers': [8, 1, 1, 8, 1, 1],
#               'fix_com': True,
#               'fix_orientation': True,
#               'fragment_charges': [0.0, 0.0],
#               'fragment_multiplicities': [1, 1],
#               'fragments': [[0, 1, 2], [3, 4, 5]],
#               'geometry': [0.0511833892557548, 2.3601595929482104, 0.0, 0.0511833892557548, 0.4704334674903823, 0.0,
#                            -1.7781852282291912, 2.833947826866142, 0.0, 0.0511833892557548, -2.1751831081505766, 0.0,
#                            0.0511833892557548, -3.1200461708794904, 1.6365508308416188, 0.0511833892557548,
#                            -3.1200461708794904, -1.6365508308416188],
#               'mass_numbers': [16, 1, 1, 16, 1, 1],
#               'masses': [15.99491461957, 1.00782503223, 1.00782503223, 15.99491461957, 1.00782503223, 1.00782503223],
#               'molecular_charge': 0.0,
#               'molecular_multiplicity': 1,
#               'name': 'H4O2',
#               'provenance': {'creator': 'QCElemental',
#                              'routine': 'qcelemental.molparse.from_string',
#                              'version': 'v0.25.0'},
#               'real': [False, False, False, True, True, True],
#               'schema_name': 'qcschema_molecule',
#               'schema_version': 2,
#               'symbols': ['O', 'H', 'H', 'O', 'H', 'H'],
#               'validated': True},
#  'protocols': {'stdout': True},
#  'provenance': {'creator': 'QCElemental', 'routine': 'qcelemental.models.results', 'version': 'v0.25.0'},
#  'schema_name': 'qcschema_input',
#  'schema_version': 1}
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
#
# *** tstart() called on Chongyes-Air.attlocal.net
# *** at Tue Sep 27 23:45:34 2022
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4     entry O          line
#
#     Final Occupation by Irrep:
#              Ap   App
#     DOCC [     4,    1 ]
#
#   @DF-RHF Final Energy:   -76.03032213364304
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.7723559757493383
#     One-Electron Energy =                -122.2632641902639250
#     Two-Electron Energy =                  37.4605860808715505
#     Total Energy =                        -76.0303221336430397
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.5113600            0.5118339            0.0004739
#  Dipole Y            :         22.9603485          -23.6415572           -0.6812087
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.6812089
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on Chongyes-Air.attlocal.net at Tue Sep 27 23:45:35 2022
# Module time:
# 	user time   =       0.49 seconds =       0.01 minutes
# 	system time =       0.05 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       0.49 seconds =       0.01 minutes
# 	system time =       0.05 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
#
#     Psi4 stopped on: Tuesday, 27 September 2022 11:45PM
#     Psi4 wall time for execution: 0:00:00.69
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.6.1 release
#
#                          Git: Rev {HEAD} 5b9f6e3
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, and A. Jiang
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     http://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Tuesday, 27 September 2022 11:45PM
#
#     Process ID: 93892
#     Host:       Chongyes-Air.attlocal.net
#     PSIDATADIR: /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4
#     Memory:     476.8 MiB
#     Threads:    1
#
#   ==> Input QCSchema <==
#
# --------------------------------------------------------------------------
# {'driver': 'energy',
#  'extras': {'psiapi': True, 'wfn_qcvars_only': True},
#  'id': None,
#  'keywords': {'function_kwargs': {}},
#  'model': {'basis': 'aug-cc-pvdz', 'method': 'scf'},
#  'molecule': {'atom_labels': ['1', '2', '3', '5', '6', '7'],
#               'atomic_numbers': [8, 1, 1, 8, 1, 1],
#               'fix_com': True,
#               'fix_orientation': True,
#               'fragment_charges': [0.0, 0.0],
#               'fragment_multiplicities': [1, 1],
#               'fragments': [[0, 1, 2], [3, 4, 5]],
#               'geometry': [0.0511833892557548, 2.3601595929482104, 0.0, 0.0511833892557548, 0.4704334674903823, 0.0,
#                            -1.7781852282291912, 2.833947826866142, 0.0, 0.0511833892557548, -2.1751831081505766, 0.0,
#                            0.0511833892557548, -3.1200461708794904, 1.6365508308416188, 0.0511833892557548,
#                            -3.1200461708794904, -1.6365508308416188],
#               'mass_numbers': [16, 1, 1, 16, 1, 1],
#               'masses': [15.99491461957, 1.00782503223, 1.00782503223, 15.99491461957, 1.00782503223, 1.00782503223],
#               'molecular_charge': 0.0,
#               'molecular_multiplicity': 1,
#               'name': 'H4O2',
#               'provenance': {'creator': 'QCElemental',
#                              'routine': 'qcelemental.molparse.from_string',
#                              'version': 'v0.25.0'},
#               'real': [True, True, True, False, False, False],
#               'schema_name': 'qcschema_molecule',
#               'schema_version': 2,
#               'symbols': ['O', 'H', 'H', 'O', 'H', 'H'],
#               'validated': True},
#  'protocols': {'stdout': True},
#  'provenance': {'creator': 'QCElemental', 'routine': 'qcelemental.models.results', 'version': 'v0.25.0'},
#  'schema_name': 'qcschema_input',
#  'schema_version': 1}
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
#
# *** tstart() called on Chongyes-Air.attlocal.net
# *** at Tue Sep 27 23:45:35 2022
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4     entry O          line   254 file /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 2-3, 5-6 entry H          line    40 file /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    476 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Bohr), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.051183389256     2.360159592948     0.000000000000    15.994914619570
#          H            0.051183389256     0.470433467490     0.000000000000     1.007825032230
#          H           -1.778185228229     2.833947826866     0.000000000000     1.007825032230
#       Gh(O)           0.051183389256    -2.175183108151     0.000000000000    15.994914619570
#       Gh(H)           0.051183389256    -3.120046170879     1.636550830842     1.007825032230
#       Gh(H)           0.051183389256    -3.120046170879    -1.636550830842     1.007825032230
#
#   Running in cs symmetry.
#
#   Rotational constants: A =      7.05499  B =      0.30715  C =      0.30364 [cm^-1]
#   Rotational constants: A = 211503.26990  B =   9208.17856  C =   9103.02103 [MHz]
#   Nuclear repulsion =    8.801420354575150
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 38
#     Number of basis functions: 82
#     Number of Cartesian functions: 86
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1, 4     entry O          line   270 file /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#     atoms 2-3, 5-6 entry H          line    70 file /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.017 GiB; user supplied 0.349 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               357
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 104
#     Number of basis functions: 300
#     Number of Cartesian functions: 342
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 1.8247433204E-03.
#   Reciprocal condition number of the overlap matrix is 2.4588332664E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A'        55      55
#      A"        27      27
#    -------------------------
#     Total      82      82
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter SAD:   -75.41487071433494   -7.54149e+01   0.00000e+00
#    @DF-RHF iter   1:   -75.94953114877116   -5.34660e-01   7.37600e-03 DIIS/ADIIS
#    @DF-RHF iter   2:   -76.00140859237368   -5.18774e-02   5.06186e-03 DIIS/ADIIS
#    @DF-RHF iter   3:   -76.03539513701406   -3.39865e-02   3.84699e-04 DIIS/ADIIS
#    @DF-RHF iter   4:   -76.03585718010413   -4.62043e-04   8.83041e-05 DIIS
#    @DF-RHF iter   5:   -76.03588736473684   -3.01846e-05   2.10045e-05 DIIS
#    @DF-RHF iter   6:   -76.03588995958103   -2.59484e-06   4.15808e-06 DIIS
#    @DF-RHF iter   7:   -76.03589006409103   -1.04510e-07   6.79188e-07 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1Ap   -20
#       40Ap     2.079442    20App    2.104928    41Ap     2.244039
#       21App    2.334880    42Ap     2.446547    22App    2.500778
#       43Ap     2.534877    44Ap     2.569291    45Ap     2.587137
#       46Ap     2.787416    47Ap     2.883715    23App    2.930266
#       48Ap     3.044980    49Ap     3.249155    24App    3.647949
#       50Ap     3.716294    51Ap     3.733501    25App    3.738889
#       52Ap     3.778337    26App    3.813384    53Ap     4.101806
#       54Ap     4.155130    27App    4.159058    55Ap     4.602925
#
#     Final Occupation by Irrep:
#              Ap   App
#     DOCC [     8,    2 ]
#
#   @DF-RHF Final Energy:  -152.05597145847975
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             39.8241438172904267
#     One-Electron Energy =                -289.0689026179257439
#     Two-Electron Energy =                  97.1887873421555497
#     Total Energy =                       -152.0559714584797462
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.2260336           -0.8057008           -0.5796673
#  Dipole Y            :         -0.2676260           -1.4558992           -1.7235251
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    1.8183930
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on Chongyes-Air.attlocal.net at Tue Sep 27 23:45:36 2022
# Module time:
# 	user time   =       0.46 seconds =       0.01 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       1.48 seconds =       0.02 minutes
# 	system time =       0.08 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
#
#     Psi4 stopped on: Tuesday, 27 September 2022 11:45PM
#     Psi4 wall time for execution: 0:00:00.51
#
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //          ManyBody Results         //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#
#    ==> N-Body: Counterpoise Corrected (CP) energies <==
#
#         n-Body     Total Energy            Interaction Energy                          N-body Contribution to Interaction Energy
#                    [Eh]                    [Eh]                  [kcal/mol]            [Eh]                  [kcal/mol]
#              1  N/A                         0.000000000000        0.000000000000        0.000000000000        0.000000000000
#   FULL/RTN   2  N/A                         0.010240739254        6.426160900577        0.010240739254        6.426160900577
#
#
# Scratch directory: /tmp/
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   // ManyBody Setup: N-Body Levels [1, 2]//
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#         Number of 1-body computations:     2
#         Number of 2-body computations:     1
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.6.1 release
#
#                          Git: Rev {HEAD} 5b9f6e3
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, and A. Jiang
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     http://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Tuesday, 27 September 2022 11:45PM
#
#     Process ID: 93892
#     Host:       Chongyes-Air.attlocal.net
#     PSIDATADIR: /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4
#     Memory:     476.8 MiB
#     Threads:    1
#
#   ==> Input QCSchema <==
#
# --------------------------------------------------------------------------
# {'driver': 'energy',
#  'extras': {'psiapi': True, 'wfn_qcvars_only': True},
#  'id': None,
#  'keywords': {'function_kwargs': {}},
#  'model': {'basis': 'aug-cc-pvdz', 'method': 'scf'},
#  'molecule': {'atom_labels': ['1', '2', '3', '5', '6', '7'],
#               'atomic_numbers': [8, 1, 1, 8, 1, 1],
#               'fix_com': True,
#               'fix_orientation': True,
#               'fragment_charges': [0.0, 0.0],
#               'fragment_multiplicities': [1, 1],
#               'fragments': [[0, 1, 2], [3, 4, 5]],
#               'geometry': [0.0511833892557548, 2.4546458992211027, 0.0, 0.0511833892557548, 0.5649197737632745, 0.0,
#                            -1.7781852282291912, 2.9284341331390342, 0.0, 0.0511833892557548, -2.269669414423468, 0.0,
#                            0.0511833892557548, -3.2145324771523813, 1.6365508308416188, 0.0511833892557548,
#                            -3.2145324771523813, -1.6365508308416188],
#               'mass_numbers': [16, 1, 1, 16, 1, 1],
#               'masses': [15.99491461957, 1.00782503223, 1.00782503223, 15.99491461957, 1.00782503223, 1.00782503223],
#               'molecular_charge': 0.0,
#               'molecular_multiplicity': 1,
#               'name': 'H4O2',
#               'provenance': {'creator': 'QCElemental',
#                              'routine': 'qcelemental.molparse.from_string',
#                              'version': 'v0.25.0'},
#               'real': [False, False, False, True, True, True],
#               'schema_name': 'qcschema_molecule',
#               'schema_version': 2,
#               'symbols': ['O', 'H', 'H', 'O', 'H', 'H'],
#               'validated': True},
#  'protocols': {'stdout': True},
#  'provenance': {'creator': 'QCElemental', 'routine': 'qcelemental.models.results', 'version': 'v0.25.0'},
#  'schema_name': 'qcschema_input',
#  'schema_version': 1}
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
#
# *** tstart() called on Chongyes-Air.attlocal.net
# *** at Tue Sep 27 23:45:36 2022
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4     entry O          line   254 file /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 2-3, 5-6 entry H          line    40 file /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    476 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Bohr), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#       Gh(O)           0.051183389256     2.454645899221     0.000000000000    15.994914619570
#       Gh(H)           0.051183389256     0.564919773763     0.000000000000     1.007825032230
#       Gh(H)          -1.778185228229     2.928434133139     0.000000000000     1.007825032230
#          O            0.051183389256    -2.269669414423     0.000000000000    15.994914619570
#          H            0.051183389256    -3.214532477152     1.636550830842     1.007825032230
#          H            0.051183389256    -3.214532477152    -1.636550830842     1.007825032230
#
#   Running in cs symmetry.
#
#   Rotational constants: A =      7.05326  B =      0.28417  C =      0.28117 [cm^-1]
#   Rotational constants: A = 211451.27089  B =   8519.31318  C =   8429.30649 [MHz]
#   Nuclear repulsion =    8.772355975749340
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 38
#     Number of basis functions: 82
#     Number of Cartesian functions: 86
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1, 4     entry O          line   270 file /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#     atoms 2-3, 5-6 entry H          line    70 file /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.017 GiB; user supplied 0.349 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               357
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 104
#     Number of basis functions: 300
#     Number of Cartesian functions: 342
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 1.8683790384E-03.
# ...
#       23App    3.704625    24App    3.903969    47Ap     3.915558
#       48Ap     3.978046    49Ap     4.221763    50Ap     4.856097
#       51Ap     4.892955    25App    4.952696    52Ap     5.236558
#       26App    5.327613    53Ap     5.572590    54Ap     6.217303
#       27App    6.818359    55Ap    33.530522
#
#     Final Occupation by Irrep:
#              Ap   App
#     DOCC [     4,    1 ]
#
#   @DF-RHF Final Energy:   -76.03569469462204
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              8.8014203545751499
#     One-Electron Energy =                -122.2743031784052761
#     Two-Electron Energy =                  37.4371881292080815
#     Total Energy =                        -76.0356946946220518
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.6850954           -1.3175347           -0.6324393
#  Dipole Y            :        -42.5173835           42.0277824           -0.4896012
#  Dipole Z            :          0.0000000            0.0000000            0.0000000
#  Magnitude           :                                                    0.7998055
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on Chongyes-Air.attlocal.net at Tue Sep 27 23:45:56 2022
# Module time:
# 	user time   =       0.42 seconds =       0.01 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      21.55 seconds =       0.36 minutes
# 	system time =       0.48 seconds =       0.01 minutes
# 	total time  =         22 seconds =       0.37 minutes
#
#     Psi4 stopped on: Tuesday, 27 September 2022 11:45PM
#     Psi4 wall time for execution: 0:00:00.47
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.6.1 release
#
#                          Git: Rev {HEAD} 5b9f6e3
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, and A. Jiang
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     http://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Tuesday, 27 September 2022 11:45PM
#
#     Process ID: 93892
#     Host:       Chongyes-Air.attlocal.net
#     PSIDATADIR: /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4
#     Memory:     476.8 MiB
#     Threads:    1
#
#   ==> Input QCSchema <==
#
# --------------------------------------------------------------------------
# {'driver': 'energy',
#  'extras': {'psiapi': True, 'wfn_qcvars_only': True},
#  'id': None,
#  'keywords': {'function_kwargs': {}},
#  'model': {'basis': 'aug-cc-pvdz', 'method': 'scf'},
#  'molecule': {'atom_labels': ['1', '2', '3', '5', '6', '7'],
#               'atomic_numbers': [8, 1, 1, 8, 1, 1],
#               'fix_com': True,
#               'fix_orientation': True,
#               'fragment_charges': [0.0, 0.0],
#               'fragment_multiplicities': [1, 1],
#               'fragments': [[0, 1, 2], [3, 4, 5]],
#               'geometry': [0.0511833892557548, 4.34437202467893, 0.0, 0.0511833892557548, 2.4546458992211018, 0.0,
#                            -1.7781852282291912, 4.818160258596862, 0.0, 0.0511833892557548, -4.159395539881296, 0.0,
#                            0.0511833892557548, -5.104258602610211, 1.6365508308416188, 0.0511833892557548,
#                            -5.104258602610211, -1.6365508308416188],
#               'mass_numbers': [16, 1, 1, 16, 1, 1],
#               'masses': [15.99491461957, 1.00782503223, 1.00782503223, 15.99491461957, 1.00782503223, 1.00782503223],
#               'molecular_charge': 0.0,
#               'molecular_multiplicity': 1,
#               'name': 'H4O2',
#               'provenance': {'creator': 'QCElemental',
#                              'routine': 'qcelemental.molparse.from_string',
#                              'version': 'v0.25.0'},
#               'real': [True, True, True, True, True, True],
#               'schema_name': 'qcschema_molecule',
#               'schema_version': 2,
#               'symbols': ['O', 'H', 'H', 'O', 'H', 'H'],
#               'validated': True},
#  'protocols': {'stdout': True},
#  'provenance': {'creator': 'QCElemental', 'routine': 'qcelemental.models.results', 'version': 'v0.25.0'},
#  'schema_name': 'qcschema_input',
#  'schema_version': 1}
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
#
# *** tstart() called on Chongyes-Air.attlocal.net
# *** at Tue Sep 27 23:45:56 2022
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4     entry O          line   254 file /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 2-3, 5-6 entry H          line    40 file /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    476 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Bohr), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.051183389256     4.344372024679     0.000000000000    15.994914619570
#          H            0.051183389256     2.454645899221     0.000000000000     1.007825032230
#          H           -1.778185228229     4.818160258597     0.000000000000     1.007825032230
#          O            0.051183389256    -4.159395539881     0.000000000000    15.994914619570
#          H            0.051183389256    -5.104258602610     1.636550830842     1.007825032230
#          H            0.051183389256    -5.104258602610    -1.636550830842     1.007825032230
#
#   Running in cs symmetry.
#
#   Rotational constants: A =      7.03523  B =      0.09068  C =      0.09038 [cm^-1]
#   Rotational constants: A = 210910.77760  B =   2718.54017  C =   2709.39763 [MHz]
#   Nuclear repulsion =   29.305354572523061
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 20
#   Nalpha       = 10
#   Nbeta        = 10
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 38
#     Number of basis functions: 82
#     Number of Cartesian functions: 86
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1, 4     entry O          line   270 file /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#     atoms 2-3, 5-6 entry H          line    70 file /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.016 GiB; user supplied 0.349 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               357
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       6.8114
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 104
#     Number of basis functions: 300
#     Number of Cartesian functions: 342
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 2.3022705755E-03.
#   Reciprocal condition number of the overlap matrix is 3.9999854727E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A'
#
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //          ManyBody Results         //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#
#    ==> N-Body: Counterpoise Corrected (CP) energies <==
#
#         n-Body     Total Energy            Interaction Energy                          N-body Contribution to Interaction Energy
#                    [Eh]                    [Eh]                  [kcal/mol]            [Eh]                  [kcal/mol]
#              1  N/A                         0.000000000000        0.000000000000        0.000000000000        0.000000000000
#   FULL/RTN   2  N/A                        -0.002165860163       -1.359097771260       -0.002165860163       -1.359097771260
#
# Finished computing the potential energy surface!

# %% [markdown]
# ## Exercise
# Plot the energies vs. separation of the two oxygen atoms (R).

# %%
print(len(energies))
print(len(rvals))
# Out:
# 14
# 14

# %%
plt.plot(rvals,energies,".-"); # look at rvals and energies
# give it an xlabel
plt.xlabel("Relative Distances")
# give it a ylabel
plt.ylabel("Potential Energies")
plt.ylim(-5, 10)
# give it a title
plt.title("Water Dimer Energy vs Rval in 1D")

plt.show()

# %% [markdown]
# ## Scan 2D PES
# Now let’s get even more detailed! Instead of simply scanning the PES along a single coordinate, let’s consider two coordinates at the same time. For this, we will choose to look at (1) the distance between the two molecules, and (2) a rotation of one of the molecules about the distance vector.
#
# To do this, the first thing we need to do is redefine our z-matrix to define the angle we want to change. To maintain the water molecule as planar, we need to adjust two dihedral angles, such that one angle is always 180 from the other. We will define one of these dihedral angles as A and the other as B.

# %%
# Define water dimer
water_dimer2 = """
O1
H2 1 1.0
H3 1 1.0 2 104.52
x4 2 1.0 1 90.0 3 180.0
--
O5 2 **R** 4 90.0 1 180.0
H6 5 1.0 2 120.0 4 **A**
H7 5 1.0 2 120.0 4 **B**
"""

# %% [markdown]
# First, let’s choose one value of R and rotate through many dihedral angles. Since we want our water to remain planar, the two dihedral angles aren’t actually independent; they must always be 180 degrees apart. Therefore, we will choose a range of values for A, and then calculate B based on the value of A. We will create a list called `energies_R` to store our energy values for this particular value of R.

# %%
R = 1.8
Avals = np.linspace(start=-180,stop=180, num=25)

energies_R = []

for A in Avals:

    print(F'Computing dimer at {R:.1f} angstroms and {A:.2f} degrees')

    # Build a new molecule at each separation
    B = A-180
    molR = water_dimer2.replace('**R**', str(R))
    molA = molR.replace('**A**', str(A))
    molB = molA.replace('**B**', str(B))
    mol = psi4.geometry(molB)

    # calculate energy
    psi4.set_output_file(F'{molecule_name}_{R:.1f}_{A:.2f}_energy.dat', False)
    E = psi4.energy('scf/aug-cc-pVDZ', molecule=mol, bsse_type='cp')       
    E = E*627.509
    energies_R.append(E)
# Out:
# Computing dimer at 1.8 angstroms and -180.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -165.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -150.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -135.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -120.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -105.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -90.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -75.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -60.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -45.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -30.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -15.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 0.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 15.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 30.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 45.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 60.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 75.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 90.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 105.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 120.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 135.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 150.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 165.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 180.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(

# %% [markdown]
# ## Exercise
# Plot the energy as a function of the dihedral angle A.

# %%
print(len(energies_R))
print(len(Avals))
# Out:
# 25
# 25

# %%
plt.figure()
plt.plot(Avals, energies_R, 'r-o') # look at Avals and energies_R
# give it xlabel and ylabel
# give it an xlabel
plt.xlabel("Relative Angle (Degree)")
# give it a ylabel
plt.ylabel("Potential Energies")
plt.ylim(-5, 10)
# give it a title
plt.title("Water Dimer Energy vs Relative Position (2D)")
# Out:
# Text(0.5, 1.0, 'Water Dimer Energy vs Relative Position (2D)')

# %% [markdown]
# Now let’s expand to two degrees of freedom. We will use the same angles as before, but now instead of just doing all the calculations at a single value of R, we will do the calculation at multiple values of R. To do this, we will use a nested *for loop*. This means we will have an outer `for` loop that counts over the different values of R and then an inner `for` loop that counts over the different values of A for a particular value of R. As we calculate the energies at each angle for a particular value of R, we will save the values in a list called `energies_R` as we did before. Once we have finished all the angles for a particular R, we will append the list `energies_R` to a list called `energy_2D`. This means `energy_2D` will be a list of lists. We will need to create `energy_2D` as an empty list outside of our `for` loop.

# %%
Rvals = np.linspace(start=1.8,stop=2.5,num=8)
Avals = np.linspace(start=-180,stop=180, num=25)

energy_2D = []

for R in Rvals:
    energies_R = []

    for A in Avals:

        print(F'Computing dimer at {R:.1f} angstroms and {A:.2f} degrees')

        # Build a new molecule at each separation
        B = A-180
        molR = water_dimer2.replace('**R**', str(R))
        molA = molR.replace('**A**', str(A))
        molB = molA.replace('**B**', str(B))
        mol = psi4.geometry(molB)

        # calculate energy
        psi4.set_output_file(F'{molecule_name}_{R:.1f}_{A:.2f}_energy.dat', False)
        E = psi4.energy('scf/aug-cc-pVDZ', molecule=mol, bsse_type='cp')       
        E = E*627.509
        energies_R.append(E)

    energy_2D.append(energies_R)

print(F'All calculations are complete!')
# Out:
# Computing dimer at 1.8 angstroms and -180.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -165.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -150.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -135.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -120.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -105.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -90.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -75.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -60.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -45.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -30.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and -15.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 0.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 15.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 30.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 45.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 60.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 75.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 90.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 105.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 120.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 135.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 150.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 165.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.8 angstroms and 180.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and -180.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and -165.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and -150.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and -135.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and -120.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and -105.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and -90.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and -75.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and -60.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and -45.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and -30.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and -15.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and 0.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and 15.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and 30.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and 45.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and 60.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and 75.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and 90.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and 105.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and 120.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and 135.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and 150.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and 165.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 1.9 angstroms and 180.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.0 angstroms and -180.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.0 angstroms and -165.00 degrees
# ...
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and -45.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and -30.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and -15.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and 0.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and 15.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and 30.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and 45.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and 60.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and 75.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and 90.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and 105.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and 120.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and 135.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and 150.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and 165.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# Computing dimer at 2.5 angstroms and 180.00 degrees
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# /Users/chongyefeng/opt/anaconda3/envs/clean-env/envs/qm-tools/lib/python3.10/site-packages/psi4/driver/task_base.py:161: FutureWarning: Using the `local_options` keyword argument is deprecated in favor of using `task_config`, in version 0.30.0 it will stop working.
#   self.result = qcng.compute(
# All calculations are complete!

# %% [markdown]
# ## Exercise
# Plot the interaction energies as a function of angle for two different values of R, 2.0 and 2.3, on the same graph.
#
# In the Rvals list, 2.0 angstrom is index 2, Rvals[2]. 2.3 angstroms is index 5, Rvals[5].

# %%
print(len(energy_2D))
# Out:
# 8

# %%
plt.figure()
plt.plot(Avals, energy_2D[2], 'r-o', label='R = 2.0 angstrom')
plt.plot(Avals, energy_2D[5], 'b-o', label='R = 2.3 angstrom')
# put in an x and ylabel
# give it an xlabel
plt.xlabel("Relative Angle (Degree)")
# give it a ylabel
plt.ylabel("Potential Energies")
plt.legend()
plt.show()

# %% [markdown]
# ## Making 3D plots
# Comparing the two graphs you just made, it is clear that the interaction energy is a function of both the seperation between the molecules and the rotation angle. We can capture this in a 3D plot using some of matplotlib’s advanced features.

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline

X, Y = np.meshgrid(Avals, Rvals)

mycmap1 = plt.get_cmap('gist_earth')

fig, (ax,ax2) = plt.subplots(1,2,figsize=(12,6))

ax = plt.axes(projection='3d')
# changed nrg_2D into energy_2D to make the plot
cf = ax.contour3D(X, Y, np.array(energy_2D), 300, cmap=mycmap1)
ax.plot_surface(X, Y, np.array(energy_2D), rstride=1, cstride=1, cmap='viridis', edgecolor='none')

ax.set_xlabel('angle (degrees)')
ax.set_ylabel('R (Bohr)')
ax.set_zlabel('energy (kcal/mol)')
#ax.set_zlim3d(-4,-2)
ax.view_init(45, 35)
